# %% [markdown]
# # Opinion Mining Tools Benchmarking
#
# In this notebook we display the results of our benchmarking of several opinion mining tools

# %% [markdown]
# ## English

# %%
import pandas as pd
import glob

results_files = glob.glob("results/en-sentiment-*.csv")


dfs = []

for file in results_files:
    dfs.append(pd.read_csv(file))

df = pd.concat(dfs, ignore_index=True)

df.set_index([])
# Out:
#             Model               Dataset  Macro F1  Macro Precision  \
# 0   pysentimiento             sent_eval  0.883274         0.887604
# 1   pysentimiento          sentiment140  0.858268         0.861730
# 2   pysentimiento                  mteb  0.756537         0.763679
# 3   pysentimiento                amazon  0.631546         0.631302
# 4   pysentimiento                  sst2  0.879472         0.879909
# 5   pysentimiento  financial_phrasebank  0.682352         0.750389
# 6           vader             sent_eval  0.729698         0.727662
# 7           vader          sentiment140  0.260184         0.694590
# 8           vader                  mteb  0.203325         0.626697
# 9           vader                amazon  0.189745         0.655918
# 10          vader                  sst2  0.667704         0.671714
# 11          vader  financial_phrasebank  0.251322         0.333713
# 12       textblob             sent_eval  0.678205         0.678455
# 13       textblob          sentiment140  0.633127         0.676318
# 14       textblob                  mteb  0.474456         0.540809
# 15       textblob                amazon  0.450305         0.515020
# 16       textblob                  sst2  0.658604         0.665002
# 17       textblob  financial_phrasebank  0.448512         0.466919
# 18         stanza             sent_eval  0.773902         0.772009
# 19         stanza          sentiment140  0.684741         0.747145
# 20         stanza                  mteb  0.519117         0.622911
# 21         stanza                amazon  0.528619         0.548585
# 22         stanza                  sst2  0.849714         0.849730
# 23         stanza  financial_phrasebank  0.441454         0.463273
#
#     Macro Recall
# 0       0.879681
# 1       0.857035
# 2       0.754023
# 3       0.633000
# 4       0.879315
# 5       0.645194
# 6       0.732663
# 7       0.390112
# 8       0.349425
# 9       0.369667
# 10      0.668519
# 11      0.333510
# 12      0.677966
# 13      0.646642
# 14      0.489655
# 15      0.472667
# 16      0.660173
# 17      0.439714
# 18      0.787035
# 19      0.702158
# 20      0.524138
# 21      0.539833
# 22      0.849699
# 23      0.444095
